# %% [markdown]
# # Loops

# %%
odds = [1, 3, 5, 7]

# %%
print(odds[0])
print(odds[1])
print(odds[2])
print(odds[3])
# Out:
# 1
# 3
# 5
# 7

# %% [markdown]
# # For Loop

# %%
odds = [1, 3, 5, 7]
for num in odds:
    print(num)
# Out:
# 1
# 3
# 5
# 7

# %%
odds = [1, 3, 5, 7, 9, 11]
for num in odds:
    print(num)
# Out:
# 1
# 3
# 5
# 7
# 9
# 11

# %%
#num is just a name - it could be anything. 
odds = [1, 3, 5, 7, 9, 11]
for banana in odds:
    print(banana)
# Out:
# 1
# 3
# 5
# 7
# 9
# 11

# %%
length = 0 
names = ['Curie', 'Darwin', 'Turing']
for value in names:
    length = length+1
print('There are ', length, 'names in the list')
# Out:
# There are  3 names in the list

# %%
name = 'Rosalind'
for name in ['Curie', 'Darwin', 'Turing']:
    print(name)
print('after the loop, name is', name)
# Out:
# Curie
# Darwin
# Turing
# after the loop, name is Turing

# %%
names = ' '
for names in ['Curie', 'Darwin', 'Turing']:
    print(names)
print('after the loop, name is', names)
# Out:
# Curie
# Darwin
# Turing
# after the loop, name is Turing

# %%
names
# Out:
# 'Turing'

# %%
for number in range(1,4):
    print(number)
# Out:
# 1
# 2
# 3

# %%
word = 'oxygen'
for letter in word:
    print(letter)

#the body of the loop is executed 6 times.
# Out:
# o
# x
# y
# g
# e
# n

# %% [markdown]
# ### Computing powers with loops

# %%
print(5**3)
# Out:
# 125

# %%
result = 1
for value in range(0,3):
    result = result*5
print(result)
# Out:
# 125

# %%
for i in range(0,3):
    print(i)
# Out:
# 0
# 1
# 2

# %%
#Write a loop that calculates the sum of elements in a list by adding each element and printing the final value, so [124, 402, 36] prints 562

total = 0
list = [124, 402, 36]
for value in list:
    total = total + value
print(total)
# Out:
# 562

# %% [markdown]
# # Challenge
# Computing the Value of a Polynomial
# The built-in function enumerate takes a sequence (e.g. a list) and generates a new sequence of the same length. Each element of the new sequence is a pair composed of the index (0, 1, 2,…) and the value from the original sequence:
#
# PYTHON
# for idx, val in enumerate(a_list):
#     # Do something using idx and val
# The code above loops through a_list, assigning the index to idx and the value to val.
#
# Suppose you have encoded a polynomial as a list of coefficients in the following way: the first element is the constant term, the second element is the coefficient of the linear term, the third is the coefficient of the quadratic term, where the polynomial is of the form 𝑎⁢𝑥0 +𝑏⁢𝑥1 +𝑐⁢𝑥2
# .
#
# PYTHON
# x = 5
# coefs = [2, 4, 3]
# y = coefs[0] * x**0 + coefs[1] * x**1 + coefs[2] * x**2
# print(y)
# OUTPUT
# 97
# Write a loop using enumerate(coefs) which computes the value y of any polynomial, given x and coefs.

# %%
y = 0
x=5
coefs = [2, 4, 3]
for idx, val in enumerate(coefs):
    y = y + val*x**idx
print(y)
# Out:
# 97
