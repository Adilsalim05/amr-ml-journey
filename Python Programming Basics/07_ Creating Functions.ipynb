# %% [markdown]
# # Creating Functions

# %%
fahrenheit_val = 99
celsius_val = ((fahrenheit_val - 32) * (5/9))

celsius_val
# Out:
# 37.22222222222222

# %%
fahrenheit_val = 99
celsius_val = ((fahrenheit_val - 32) * (5/9))

fahrenheit_val2 = 43
celsius_val2 = ((fahrenheit_val2 - 32) * (5/9))

# %% [markdown]
# ## defining function for F to C

# %%
def explicit_fahr_to_Celsius(temp):
    #assign convertable value to a variable
    converted  = ((temp - 32)* (5/9))
    # Return the value of the new variable
    return converted

# %%
def fahr_to_celsius(temp):
    # Return converted value more efficiently using the return
    # function without creating a new variable. This code does
    # the same thing as the previous function but it is more explicit
    # in explaining how the return command works.
    return ((temp - 32) * (5/9))

# %%
fahr_to_celsius(100)
# Out:
# 37.77777777777778

# %%
def C_to_Fehr (temp_C):
    return((temp_C * 1.8 + 32))

# %%
C_to_Fehr(37.78)
# Out:
# 100.004

# %%
print('freezing point of water:', fahr_to_celsius(32), 'C')
# Out:
# freezing point of water: 0.0 C

# %%
print('boiling point of water:', fahr_to_celsius(212), 'C')
# Out:
# boiling point of water: 100.0 C

# %%
print('freezing point of water:', C_to_Fehr(0), 'F')
print('boiling point of water:', C_to_Fehr(100), 'F')
# Out:
# freezing point of water: 32.0 F
# boiling point of water: 212.0 F

# %%
def celsius_to_kelvin(temp_c):
    return temp_c + 273.15

print('freezing point of water in Kelvin:', celsius_to_kelvin(0.))
# Out:
# freezing point of water in Kelvin: 273.15

# %%
def fehr_to_kelvin(temp_f):
    temp_c = fahr_to_celsius(temp_f)
    temp_k = celsius_to_kelvin(temp_c)
    return temp_k

# %%
print(fehr_to_kelvin(109))
# Out:
# 315.92777777777775

# %% [markdown]
# ### Tidying up

# %%
# visulizing inflammation data. 

def visualize(filename):

    data = numpy.loadtxt(fname=filename, delimiter=',')

    fig = matplotlib.pyplot.figure(figsize=(10.0, 3.0))

    axes1 = fig.add_subplot(1, 3, 1)
    axes2 = fig.add_subplot(1, 3, 2)
    axes3 = fig.add_subplot(1, 3, 3)

    axes1.set_ylabel('average')
    axes1.plot(numpy.mean(data, axis=0))

    axes2.set_ylabel('max')
    axes2.plot(numpy.max(data, axis=0))

    axes3.set_ylabel('min')
    axes3.plot(numpy.min(data, axis=0))

    fig.tight_layout()
    matplotlib.pyplot.show()

# %% [markdown]
# ####

# %% [markdown]
# #### Another function called detect_problems that check for those systemic problems

# %%
def detect_problems(filename):

    data = numpy.loadtxt(fname=filename, delimiter=',')

    if numpy.max(data, axis=0)[0] == 0 and numpy.max(data, axis=0)[20] == 20:
        print('Suspicious looking maxima!')
    elif numpy.sum(numpy.min(data, axis=0)) == 0:
        print('Minima add up to zero!')
    else:
        print('Seems OK!')

# %%
import glob
import numpy
import matplotlib.pyplot

filenames = sorted(glob.glob('data/inflammation*.csv'))

for filename in filenames:
    print(filename)
    visualize(filename)
    detect_problems(filename)
# Out:
# data/inflammation-01.csv
# Suspicious looking maxima!
# data/inflammation-02.csv
# Suspicious looking maxima!
# data/inflammation-03.csv
# Minima add up to zero!
# data/inflammation-04.csv
# Suspicious looking maxima!
# data/inflammation-05.csv
# Suspicious looking maxima!
# data/inflammation-06.csv
# Suspicious looking maxima!
# data/inflammation-07.csv
# Suspicious looking maxima!
# data/inflammation-08.csv
# Minima add up to zero!
# data/inflammation-09.csv
# Suspicious looking maxima!
# data/inflammation-10.csv
# Suspicious looking maxima!
# data/inflammation-11.csv
# Minima add up to zero!
# data/inflammation-12.csv
# Suspicious looking maxima!

# %% [markdown]
# ## Testing and Documenting

# %%
def offset_mean (data, target_mean_value):
    return (data - numpy.mean(data)) + target_mean_value

# %%
z = numpy.zeros((2, 2))
print(offset_mean(z, 3))
# Out:
# [[3. 3.]
#  [3. 3.]]

# %%
# trying offset mean on our real data

data = numpy.loadtxt(fname='data/inflammation-01.csv', delimiter=',')
print(offset_mean(data, 0))
# Out:
# [[-6.14875 -6.14875 -5.14875 ... -3.14875 -6.14875 -6.14875]
#  [-6.14875 -5.14875 -4.14875 ... -5.14875 -6.14875 -5.14875]
#  [-6.14875 -5.14875 -5.14875 ... -4.14875 -5.14875 -5.14875]
#  ...
#  [-6.14875 -5.14875 -5.14875 ... -5.14875 -5.14875 -5.14875]
#  [-6.14875 -6.14875 -6.14875 ... -6.14875 -4.14875 -6.14875]
#  [-6.14875 -6.14875 -5.14875 ... -5.14875 -5.14875 -6.14875]]

# %%
print('original min, mean, and max are:', numpy.min(data), numpy.mean(data), numpy.max(data))
offset_data = offset_mean(data, 0)
print('min, mean, and max of offset data are:',
      numpy.min(offset_data),
      numpy.mean(offset_data),
      numpy.max(offset_data))
# Out:
# original min, mean, and max are: 0.0 6.14875 20.0
# min, mean, and max of offset data are: -6.14875 2.842170943040401e-16 13.85125

# %%
print('std dev before and after:', numpy.std(data), numpy.std(offset_data))
# Out:
# std dev before and after: 4.613833197118566 4.613833197118566

# %%
print('difference in standard deviations before and after:',
      numpy.std(data) - numpy.std(offset_data))
# Out:
# difference in standard deviations before and after: 0.0

# %%
# offset_mean(data, target_mean_value):
# return a new array containing the original data with its mean offset to match the desired value.
def offset_mean(data, target_mean_value):
    return (data - numpy.mean(data)) + target_mean_value

# %%
def offset_mean(data, target_mean_value):
    """Return a new array containing the original data
       with its mean offset to match the desired value."""
    return (data - numpy.mean(data)) + target_mean_value

# %%
help(offset_mean)
# Out:
# Help on function offset_mean in module __main__:
#
# offset_mean(data, target_mean_value)
#     Return a new array containing the original data
#     with its mean offset to match the desired value.

# %%
def offset_mean(data, target_mean_value):
    """Return a new array containing the original data
       with its mean offset to match the desired value.

    Examples
    --------
    >>> offset_mean([1, 2, 3], 0)
    array([-1.,  0.,  1.])
    """
    return (data - numpy.mean(data)) + target_mean_valueb

# %%
test_data = numpy.zeros((2, 2))
print(offset_mean(test_data, 3))
# Out:
# [[3. 3.]
#  [3. 3.]]

# %%
def offset_mean(data, target_mean_value=0.0):
    """Return a new array containing the original data
       with its mean offset to match the desired value, (0 by default).

    Examples
    --------
    >>> offset_mean([1, 2, 3])
    array([-1.,  0.,  1.])
    """
    return (data - numpy.mean(data)) + target_mean_value

# %%
more_data = 5 + numpy.zeros((2, 2))
print('data before mean offset:')
print(more_data)
print('offset data:')
print(offset_mean(more_data))
# Out:
# data before mean offset:
# [[5. 5.]
#  [5. 5.]]
# offset data:
# [[0. 0.]
#  [0. 0.]]

# %%
def display(a=1, b=2, c=3):
    print('a:', a, 'b:', b, 'c:', c)

print('no parameters:')
display()
print('one parameter:')
display(55)
print('two parameters:')
display(55, 66)
# Out:
# no parameters:
# a: 1 b: 2 c: 3
# one parameter:
# a: 55 b: 2 c: 3
# two parameters:
# a: 55 b: 66 c: 3

# %%
print('only setting the value of c')
display(c=77)
# Out:
# only setting the value of c
# a: 1 b: 2 c: 77

# %%
numpy.loadtxt('data/inflammation-01.csv', ',')
# Out:
# Traceback (most recent call last):
#
#   File ~/Downloads/yes/envs/bioml/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3748 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[58], line 1
#     numpy.loadtxt('data/inflammation-01.csv', ',')
#
#   File ~/Downloads/yes/envs/bioml/lib/python3.11/site-packages/numpy/lib/_npyio_impl.py:1384 in loadtxt
#     arr = _read(fname, dtype=dtype, comment=comment, delimiter=delimiter,
#
#   File ~/Downloads/yes/envs/bioml/lib/python3.11/site-packages/numpy/lib/_npyio_impl.py:937 in _read
#     dtype = np.dtype(dtype)
#
#   File ~/Downloads/yes/envs/bioml/lib/python3.11/site-packages/numpy/_core/_internal.py:205 in _commastring
#     newitem = (dtype, ast.literal_eval(repeats))
#
#   File ~/Downloads/yes/envs/bioml/lib/python3.11/ast.py:64 in literal_eval
#     node_or_string = parse(node_or_string.lstrip(" \t"), mode='eval')
#
#   File ~/Downloads/yes/envs/bioml/lib/python3.11/ast.py:50 in parse
# ...

# %%
def s(p):
    a = 0
    for v in p:
        a += v
    m = a / len(p)
    d = 0
    for v in p:
        d += (v - m) * (v - m)
    return numpy.sqrt(d / (len(p) - 1))

def std_dev(sample):
    sample_sum = 0
    for value in sample:
        sample_sum += value

    sample_mean = sample_sum / len(sample)

    sum_squared_devs = 0
    for value in sample:
        sum_squared_devs += (value - sample_mean) * (value - sample_mean)

    return numpy.sqrt(sum_squared_devs / (len(sample) - 1))

# %% [markdown]
# # things got very complecated here. I am leaving it here for now.

# %%
def sequence_summary(seq):
    seq = seq.upper()
    return {
        "length": len(seq),
        "A": seq.count("A"),
        "T": seq.count("T"),
        "G": seq.count("G"),
        "C": seq.count("C"),
    }

print(sequence_summary("ATGCGATCGATCG"))
# Out:
# {'length': 13, 'A': 3, 'T': 3, 'G': 4, 'C': 3}

# %%
def sequence_summary(seq):
    seq = seq.upper()
    return {
        "length": len(seq), 
        "A": seq.count('A'), 
        "T": seq.count('T'),
        "C": seq.count('C'),
        "G": seq.count('G'),
    } 

print(sequence_summary('AAATCGTTTCGCGTTCCAATCG'))
# Out:
# {'length': 22, 'A': 5, 'T': 7, 'C': 6, 'G': 4}
