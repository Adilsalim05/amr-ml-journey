# %% [markdown]
# # Day 13 (Light) — First look at CARD

# %%
import json

with open("data/card/card.json") as f:
    card = json.load(f)

print(f"Total entries in CARD: {len(card)}")

# Look at the structure of one entry
sample_key = list(card.keys())[3]  # skip the first few metadata keys
print(sample_key, "->", type(card[sample_key]))
# Out:
# Total entries in CARD: 6445
# 7 -> <class 'dict'>

# %%
echo 'data/card/*.tar.bz2' >> ~/Projects/amr-ml-journey/.gitignore
# Out:
#   Cell In[3], line 1
#     echo 'data/card/*.tar.bz2' >> ~/Projects/amr-ml-journey/.gitignore
#          ^
# SyntaxError: invalid syntax

# %%
nano .getignore
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 nano .getignore
#
# NameError: name 'nano' is not defined
